# %% [markdown]
# <a href="https://colab.research.google.com/github/Lucaschewitch/University/blob/main/Extra_Tasks/Ex_Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

good_answer = random.randint(1, 100)
print(f"Компьютер загадал число! ({good_answer})")
count = 0
while True:
  answer = input('Введите число: ')

  if answer.lower() == "Выход":
    break

  elif not(answer.isdigit()):
    print("Ошибка!")
    continue

  answer = int(answer)
  count +=1
  if answer == good_answer:
    print(f"Поздравляем! Вы угадали число за {count} попыток(-и)!")
    break
  elif answer < good_answer:
    print("Ваше число меньше!")
  elif answer > good_answer:
    print("Ваше число больше!")
# Out:
# Компьютер загадал число! (88)
# Введите число: 3
# Ваше число меньше!
# Введите число: 89
# Ваше число больше!
# Введите число: 88
# Поздравляем! Вы угадали число за 3 попыток(-и)!
